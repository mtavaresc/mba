# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('../data/data.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# data has many countries, choose any one for check.
df.Country.value_counts().head()
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Name: Country, dtype: int64

# %%
# using only France country data for now; can check for other as well..
dff = df[df.Country == 'France']

# %%
# some space are there in description; need to remove else later operation it will create problem..
dff.loc[:, 'Description'] = dff.loc[:, 'Description'].str.strip()
# Out:
# c:\Users\Maserati\.env\mba\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# some of transaction quantity is negative which can not be possible remove them.
dff = dff[dff.Quantity > 0]

# %%
dff.head(10)
# Out:
#    InvoiceNo StockCode                         Description  Quantity  \
# 26    536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727            ALARM CLOCK BAKELIKE RED        24
# 28    536370     22726          ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724     PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                     STARS GIFT TAPE        24
# 31    536370     10002          INFLATABLE POLITICAL GLOBE        48
# 32    536370     21791   VINTAGE HEADS AND TAILS CARD GAME        24
# 33    536370     21035      SET/2 RED RETROSPOT TEA TOWELS        18
# 34    536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND        24
# 35    536370     22629                  SPACEBOY LUNCH BOX        24
#
#        InvoiceDate  UnitPrice  CustomerID Country
# 26  12/1/2010 8:45       3.75     12583.0  France
# 27  12/1/2010 8:45       3.75     12583.0  France
# 28  12/1/2010 8:45       3.75     12583.0  France
# ...

# %%
# convert data in format which is required
# converting using pivot table and Quantity sum as values. fill 0 if any nan values

basket = pd.pivot_table(
    data=dff,
    index='InvoiceNo',
    columns='Description',
    aggfunc='sum',
    fill_value=0
)

# %%
basket = basket.CustomerID
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# ...

# %%
# this to check correctness after binning it to 1..
basket['10 COLOUR SPACEBOY PEN'].head(10)
# Out:
# InvoiceNo
# 536370        0
# 536852        0
# 536974        0
# 537065        0
# 537463        0
# 537468    12567
# 537693        0
# 537897        0
# 537967        0
# 538008        0
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
# we dont need quantity sum
# we need either has taken or not
# so if user has taken that item mark as 1 else mark as 0.

def convert_into_binary(x):
    return 1 if x > 0 else 0

# %%
basket_sets = basket.applymap(convert_into_binary)

# %%
# check : has quantity now converted to 1 or 0.
basket_sets['10 COLOUR SPACEBOY PEN'].head(10)
# Out:
# InvoiceNo
# 536370    0
# 536852    0
# 536974    0
# 537065    0
# 537463    0
# 537468    1
# 537693    0
# 537897    0
# 537967    0
# 538008    0
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
# remove postage item as it is just a seal which almost all transaction contains.
print(basket_sets['POSTAGE'].head())

basket_sets.drop(columns=['POSTAGE'], inplace=True)
# Out:
# InvoiceNo
# 536370    1
# 536852    1
# 536974    1
# 537065    1
# 537463    1
# Name: POSTAGE, dtype: int64

# %%
# call apriori function and pass minimum support here we are passing 7%.
# means 7 times in total number of transaction the item should be present.
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
# Out:
# c:\Users\Maserati\.env\mba\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,

# %%
# it will generate frequent itemsets
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4   0.076531                     (BAKING SET 9 PIECE RETROSPOT)
# 5   0.071429                     (CHILDRENS CUTLERY DOLLY GIRL)
# 6   0.099490                             (DOLLY GIRL LUNCH BOX)
# 7   0.096939                          (JUMBO BAG RED RETROSPOT)
# 8   0.076531                       (JUMBO BAG WOODLAND ANIMALS)
# 9   0.125000                           (LUNCH BAG APPLE DESIGN)
# 10  0.084184                      (LUNCH BAG DOLLY GIRL DESIGN)
# 11  0.153061                          (LUNCH BAG RED RETROSPOT)
# 12  0.119898                        (LUNCH BAG SPACEBOY DESIGN)
# 13  0.117347                               (LUNCH BAG WOODLAND)
# ...

# %%
# we would apply association rules on frequent itemset.
# here we are setting based on lift and keeping minimum lift as 1.

rules_mlxtend = association_rules(
    frequent_itemsets,
    metric='lift',
    min_threshold=1
)
rules_mlxtend.head()
# Out:
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 2    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 4   (ALARM CLOCK BAKELIKE PINK)    (ALARM CLOCK BAKELIKE RED)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.102041            0.096939  0.073980    0.725000  7.478947
# 1            0.096939            0.102041  0.073980    0.763158  7.478947
# 2            0.094388            0.096939  0.079082    0.837838  8.642959
# 3            0.096939            0.094388  0.079082    0.815789  8.642959
# 4            0.102041            0.094388  0.073980    0.725000  7.681081
#
#    leverage  conviction  zhangs_metric
# 0  0.064088    3.283859       0.964734
# 1  0.064088    3.791383       0.959283
# ...

# %%
# rules_mlxtend.rename(columns={'antecedents': 'lhs', 'consequents': 'rhs'})

# as based business use case we can sort based on confidence and lift.
rules_mlxtend[
    (rules_mlxtend['lift'] >= 4) & (rules_mlxtend['confidence'] >= 0.8)
].head()
# Out:
#                         antecedents                           consequents  \
# 2        (ALARM CLOCK BAKELIKE RED)          (ALARM CLOCK BAKELIKE GREEN)
# 3      (ALARM CLOCK BAKELIKE GREEN)            (ALARM CLOCK BAKELIKE RED)
# 17  (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 18  (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)
# 19    (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 2             0.094388            0.096939  0.079082    0.837838  8.642959
# 3             0.096939            0.094388  0.079082    0.815789  8.642959
# 17            0.127551            0.132653  0.102041    0.800000  6.030769
# 18            0.127551            0.137755  0.122449    0.960000  6.968889
# 19            0.137755            0.127551  0.122449    0.888889  6.968889
#
#     leverage  conviction  zhangs_metric
# ...
